# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
import csv
import gmaps

# Google API Key
from config import gkey

# Configure gmaps with API key
gmaps.configure(api_key=gkey)

# %matplotlib inline

# %%
# Import CSV
g_lookup_pd = pd.read_csv("Resources/Data Filtration.csv")
g_lookup_pd.head()
# Out:
#   restaurant_name inspection_type inspection_date  inspection_score  \
# 0            2204         Routine      06/28/2019                95
# 1           13209         Routine      08/07/2019                96
# 2            7-11         Routine      12/18/2019                80
# 3            7-11         Routine      04/15/2019                93
# 4            7-11         Routine      02/25/2019                84
#
#    street_number street_name street_unit zip_code         street_address  \
# 0           2204         ELM         NaN    75201        3922 SIMPSON ST
# 1          13209    C F HAWN         NaN    75253      1910 S HARWOOD ST
# 2           1102       KIEST         NaN    75224      1201 ELM ST #LL09
# 3            225    COLORADO         NaN    75203        4103 LEMMON AVE
# 4          10468     GARLAND         NaN    75218  10969 N STEMMONS FRWY
#
#   inspection_month inspection_year        lat       long  Unique Join
# 0         Jun 2019          FY2019  39.811585 -94.834959          NaN
# 1         Aug 2019          FY2019  32.677500 -96.604348          NaN
# 2         Dec 2019          FY2020  32.705756 -96.840532          NaN
# 3         Apr 2019          FY2019  32.758575 -96.820548          NaN
# 4         Feb 2019          FY2019  32.842646 -96.691170          NaN

# %%
# Add columns if needed
# Note that we used "" to specify initial entry.

g_lookup_pd["google_lat"] = ""
g_lookup_pd["google_long"] = ""
#g_lookup_pd["col_name"] = ""
#g_lookup_pd["col_name"] = ""
#g_lookup_pd["col_name"] = ""
#g_lookup_pd["col_name"] = ""

g_lookup_pd.head()
# Out:
#   restaurant_name inspection_type inspection_date  inspection_score  \
# 0            2204         Routine      06/28/2019                95
# 1           13209         Routine      08/07/2019                96
# 2            7-11         Routine      12/18/2019                80
# 3            7-11         Routine      04/15/2019                93
# 4            7-11         Routine      02/25/2019                84
#
#    street_number street_name street_unit zip_code         street_address  \
# 0           2204         ELM         NaN    75201        3922 SIMPSON ST
# 1          13209    C F HAWN         NaN    75253      1910 S HARWOOD ST
# 2           1102       KIEST         NaN    75224      1201 ELM ST #LL09
# 3            225    COLORADO         NaN    75203        4103 LEMMON AVE
# 4          10468     GARLAND         NaN    75218  10969 N STEMMONS FRWY
#
#   inspection_month inspection_year        lat       long  Unique Join  \
# 0         Jun 2019          FY2019  39.811585 -94.834959          NaN
# 1         Aug 2019          FY2019  32.677500 -96.604348          NaN
# 2         Dec 2019          FY2020  32.705756 -96.840532          NaN
# 3         Apr 2019          FY2019  32.758575 -96.820548          NaN
# 4         Feb 2019          FY2019  32.842646 -96.691170          NaN
#
#   google_lat google_long
# 0
# 1
# 2
# 3
# 4

# %%
# Rename columns for readability
g_lookup_pd_rn = g_lookup_pd.rename(columns={"restaurant_name": "Restaurant",
                                            "inspection_date": "Inspection Date",
                                            "inspection_score": "Inspection Score",
                                            "street_number": "Street Number",
                                             "street_name": "Street Name",
                                             "zip_code": "Zip",
                                             "street_address": "Street Address",
                                             "lat": "Lat",
                                             "long": "Long",
                                             "google_lat": "G.Lat",
                                             "google_long": "G.Long", 
                                                })
g_lookup_pd_rn
# Out:
#                Restaurant inspection_type Inspection Date  Inspection Score  \
# 0                    2204         Routine      06/28/2019                95
# 1                   13209         Routine      08/07/2019                96
# 2                    7-11         Routine      12/18/2019                80
# 3                    7-11         Routine      04/15/2019                93
# 4                    7-11         Routine      02/25/2019                84
# ...                   ...             ...             ...               ...
# 5559  ZOE'S KITCHEN #0031         Routine      11/06/2019                88
# 5560  ZOE'S KITCHEN #0031         Routine      05/23/2019                88
# 5561         ZRG CONCEPTS         Routine      09/16/2019                96
# 5562         ZRG CONCEPTS         Routine      08/22/2019                86
# 5563         ZRG CONCEPTS         Routine      03/02/2019                90
#
#       Street Number Street Name street_unit    Zip           Street Address  \
# 0              2204         ELM         NaN  75201          3922 SIMPSON ST
# 1             13209    C F HAWN         NaN  75253        1910 S HARWOOD ST
# 2              1102       KIEST         NaN  75224        1201 ELM ST #LL09
# 3               225    COLORADO         NaN  75203          4103 LEMMON AVE
# 4             10468     GARLAND         NaN  75218    10969 N STEMMONS FRWY
# ...             ...         ...         ...    ...                      ...
# 5559           2009      ABRAMS         NaN  75214      3312 N BUCKNER BLVD
# 5560           2009      ABRAMS         NaN  75214  3312 N BUCKNER BLVD 205
# 5561           2505    FITZHUGH         NaN  75204           527 SUNSET AVE
# 5562           2505    FITZHUGH         NaN  75204            528 S HALL ST
# 5563           2505    FITZHUGH         NaN  75204         530 CENTRE ST #C
#
#      inspection_month inspection_year        Lat       Long  Unique Join  \
# 0            Jun 2019          FY2019  39.811585 -94.834959          NaN
# 1            Aug 2019          FY2019  32.677500 -96.604348          NaN
# 2            Dec 2019          FY2020  32.705756 -96.840532          NaN
# 3            Apr 2019          FY2019  32.758575 -96.820548          NaN
# 4            Feb 2019          FY2019  32.842646 -96.691170          NaN
# ...               ...             ...        ...        ...          ...
# 5559         Nov 2019          FY2020  28.835643 -81.654156          NaN
# 5560         May 2019          FY2019  28.835643 -81.654156          NaN
# 5561         Sep 2019          FY2019  32.812409 -96.783502          NaN
# 5562         Aug 2019          FY2019  32.812409 -96.783502          NaN
# 5563         Mar 2019          FY2019  32.812409 -96.783502          NaN
#
#      G.Lat G.Long
# 0
# 1
# 2
# 3
# 4
# ...    ...    ...
# 5559
# 5560
# 5561
# 5562
# 5563
#
# [5564 rows x 16 columns]

# %%
# Organize the columns so they are in a more logical order

g_lookup_pd_org = g_lookup_pd_rn[[
    "Restaurant", "Inspection Date", "Inspection Score", "Street Address", "Zip", "Lat", "Long", "G.Lat", "G.Long"]]

g_lookup_pd_org
# Out:
#                Restaurant Inspection Date  Inspection Score  \
# 0                    2204      06/28/2019                95
# 1                   13209      08/07/2019                96
# 2                    7-11      12/18/2019                80
# 3                    7-11      04/15/2019                93
# 4                    7-11      02/25/2019                84
# ...                   ...             ...               ...
# 5559  ZOE'S KITCHEN #0031      11/06/2019                88
# 5560  ZOE'S KITCHEN #0031      05/23/2019                88
# 5561         ZRG CONCEPTS      09/16/2019                96
# 5562         ZRG CONCEPTS      08/22/2019                86
# 5563         ZRG CONCEPTS      03/02/2019                90
#
#                Street Address    Zip        Lat       Long G.Lat G.Long
# 0             3922 SIMPSON ST  75201  39.811585 -94.834959
# 1           1910 S HARWOOD ST  75253  32.677500 -96.604348
# 2           1201 ELM ST #LL09  75224  32.705756 -96.840532
# 3             4103 LEMMON AVE  75203  32.758575 -96.820548
# 4       10969 N STEMMONS FRWY  75218  32.842646 -96.691170
# ...                       ...    ...        ...        ...   ...    ...
# 5559      3312 N BUCKNER BLVD  75214  28.835643 -81.654156
# 5560  3312 N BUCKNER BLVD 205  75214  28.835643 -81.654156
# 5561           527 SUNSET AVE  75204  32.812409 -96.783502
# 5562            528 S HALL ST  75204  32.812409 -96.783502
# 5563         530 CENTRE ST #C  75204  32.812409 -96.783502
#
# [5564 rows x 9 columns]

# %%
# Apply filters for testing (set limit)

# Create a copy of re-organized Data
g_lookup_pd_filter = g_lookup_pd_org.copy()

# Filter by Inspection Score
#g_lookup_pd_filter = g_lookup_pd_filter[g_lookup_pd_filter['Inspection Score'] == 100]

g_lookup_pd_filter = g_lookup_pd_filter[g_lookup_pd_filter['Street Address'] =="5315 Greenville Ave #125"]

# Filter by Zip
#g_lookup_pd_filter = g_lookup_pd_filter[g_lookup_pd_filter['Zip'] == "75237"]

# Drop null values
#g_lookup_pd_filter = g_lookup_pd_filter.dropna()
#g_lookup_pd_filter = g_lookup_pd_filter.reset_index()

g_lookup_pd_filter
# Out:
# Empty DataFrame
# Columns: [Restaurant, Inspection Date, Inspection Score, Street Address, Zip, Lat, Long, G.Lat, G.Long]
# Index: []

# %%
# create a params dict that will be updated with new city each iteration
params = {"key": gkey}

# Loop through the g_lookup_pd_org and run a lat/long search for each city
for index, row in g_lookup_pd_filter.iterrows():
    try:
        base_url = "https://maps.googleapis.com/maps/api/geocode/json"

        street = row['Street Address']
        zip_code = row['Zip']

        # update address key value
        params['address'] = f"{street},{zip_code}"

        # make request
        cities_lat_lng = requests.get(base_url, params=params)

        # print the cities_lat_lng url, avoid doing for public github repos in order to avoid exposing key


        # convert to json
        cities_lat_lng = cities_lat_lng.json()


        
        g_lookup_pd_filter.loc[index, "G.Lat"] = cities_lat_lng["results"][0]["geometry"]["location"]["lat"]
        g_lookup_pd_filter.loc[index, "G.Long"] = cities_lat_lng["results"][0]["geometry"]["location"]["lng"]
        

    except:
        print("Not found. Keeping calm and carrying on.")

        
        pass

# %%
remove_empty_lat_long = g_lookup_pd_filter.copy()



remove_empty_lat_long
# Out:
#                              Restaurant Inspection Date  Inspection Score  \
# 3673  PLATINUM #3078 CHEF'S CORNER EAST      02/19/2019               100
#
#            Street Address    Zip       Lat       Long    G.Lat   G.Long
# 3673  511 N AKARD ST #101  75201  32.79008 -96.811316  32.7838 -96.8008

# %%
# Organize the columns so they are in a more logical order
drop_old_lat_long = g_lookup_pd_filter.copy()
drop_old_lat_long = drop_old_lat_long[[
    "Restaurant", "Inspection Date", "Inspection Score", "Street Address", "Zip", "G.Lat", "G.Long"]]

# Rename G.Lat and G.Long
drop_old_lat_long_rn = drop_old_lat_long.rename(columns={"G.Lat": "Lat",
                                                        "G.Long": "Long"})
drop_old_lat_long_rn

# %%
# Save as CSV
g_lookup_pd_filter.to_csv("Google Lat Long Error2.csv")

# %%
# Plot Heatmap
fig = gmaps.figure()

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = g_lookup_pd_filter[["G.Lat", "G.Lng"]]
inspection_score = g_lookup_pd_filter["Inspection Score"].astype(int)

# Create a poverty Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations,weights=inspection_score, 
                                 dissipating=False, max_intensity=80,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
