# %%
# import yelp
import pandas as pd
# import numpy as np
import requests
import json

# bring in and use citipy to determine city based on latitude and longitude
from citipy import citipy

# import api keys
from config import yelp_api_key_Austin, yelp_api_key_Shane, yelp_client_id_Shane

# %%
# Dallas, TX, US Lat/Long: 32.7767° N, 96.7970° W
dallas_lat = 32.7767
dallas_lng = -96.7970

# testcity = citipy.nearest_city(dallas_lat,dallas_lng).city_name
testcity = citipy.nearest_city(dallas_lat,dallas_lng).city_name
print(testcity)
# Out:
# dallas

# %%
# set API key variables to pass through get request
api_key_1 = yelp_api_key_Shane
api_key_2 = yelp_api_key_Austin
# headers = {'Authorization': 'Bearer %s' % api_key}
headers_1 = {'Authorization': 'Bearer %s' % api_key_1}
headers_2 = {'Authorization': 'Bearer %s' % api_key_2}

# set url
url = 'https://api.yelp.com/v3/businesses/search'
#     'https://api.yelp.com/v3/businesses/{id}''

# set parameters
params = {"term": "restaurant", # STRING - Optional. Search term, for example "food" or "restaurants". The term may also be business names, such as "Starbucks". If term is not included the endpoint will default to searching across businesses from a small number of popular categories.
#           "location": "Dallas", # STRING - Required if either latitude or longitude is not provided. This string indicates the geographic area to be used when searching for businesses. Examples: "New York City", "NYC", "350 5th Ave, New York, NY 10118". Businesses returned in the response may not be strictly within the specified location.
          "latitude": dallas_lat, # DECIMAL - Required if location is not provided. Latitude of the location you want to search nearby.
          "longitude": dallas_lng, # DECIMAL - Required if location is not provided. Longitude of the location you want to search nearby.
          "radius": 5000, # INT - Optional. A suggested search radius in meters. This field is used as a suggestion to the search. The actual search radius may be lower than the suggested radius in dense urban areas, and higher in regions of less business density. If the specified value is too large, a AREA_TOO_LARGE error may be returned. The max value is 40000 meters (about 25 miles).
#           "categories": , # STRING - Optional. Categories to filter the search results with. See the list of supported categories. The category filter can be a list of comma delimited categories. For example, "bars,french" will filter by Bars OR French. The category identifier should be used (for example "discgolf", not "Disc Golf").
#           "locale": , # STRING - Optional. Specify the locale into which to localize the business information. See the list of supported locales. Defaults to en_US.
          "limit": 50, # INT - Optional. Number of business results to return. By default, it will return 20. Maximum is 50.
#           "offset": , # INT - Optional. Offset the list of returned business results by this amount.
#           "sort_by": , # STRING - Optional. Suggestion to the search algorithm that the results be sorted by one of the these modes: best_match, rating, review_count or distance. The default is best_match. Note that specifying the sort_by is a suggestion (not strictly enforced) to Yelp's search, which considers multiple input parameters to return the most relevant results. For example, the rating sort is not strictly sorted by the rating value, but by an adjusted rating value that takes into account the number of ratings, similar to a Bayesian average. This is to prevent skewing results to businesses with a single review.
#           "price": , # STRING - Optional. Pricing levels to filter the search result with: 1 = $, 2 = $$, 3 = $$$, 4 = $$$$. The price filter can be a list of comma delimited pricing levels. For example, "1, 2, 3" will filter the results to show the ones that are $, $$, or $$$.
#           "open_now": , # BOOLEAN - Optional. Default to false. When set to true, only return the businesses open now. Notice that open_at and open_now cannot be used together.
#           "open_at": , # INT - Optional. An integer represending the Unix time in the same timezone of the search location. If specified, it will return business open at the given time. Notice that open_at and open_now cannot be used together.
#           "attributes": , # STRING - You can combine multiple attributes by providing a comma separated like "attribute1,attribute2". If multiple attributes are used, only businesses that satisfy ALL attributes will be returned in search results. For example, the attributes "hot_and_new,cashback" will return businesses that are Hot and New AND offer Cash Back.
         }

# %%
# API request
yelp_response = requests.get(url, params=params, headers=headers_1).json()

# %%
# set yelp_results to the "businesses" data
yelp_results = yelp_response["businesses"]
total_results = yelp_response["total"]
region_center_lat = yelp_response["region"]["center"]["latitude"]
region_center_lng = yelp_response["region"]["center"]["longitude"]
# yelp_response
# yelp_results
# total_results
# region_center_lat
# region_center_lng

# %%
# pretty print yelp_results
print(json.dumps(yelp_results, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "alias": "pecan-lodge-dallas-3",
#         "categories": [
#             {
#                 "alias": "sandwiches",
#                 "title": "Sandwiches"
#             },
#             {
#                 "alias": "bbq",
#                 "title": "Barbeque"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.7835884,
#             "longitude": -96.7838669
#         },
#         "display_phone": "(214) 748-8900",
#         "distance": 1452.520750911696,
#         "id": "ycL1qii6EpKXoLgMMboBIQ",
#         "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/9aPP6Dp7IDXh6cjLlp33cg/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "2702 Main St",
#             "address2": "",
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "2702 Main St",
#                 "Dallas, TX 75226"
#             ],
#             "state": "TX",
#             "zip_code": "75226"
#         },
#         "name": "Pecan Lodge",
#         "phone": "+12147488900",
#         "price": "$$",
#         "rating": 4.5,
#         "review_count": 4779,
#         "transactions": [],
#         "url": "https://www.yelp.com/biz/pecan-lodge-dallas-3?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "cava-dallas-2",
#         "categories": [
#             {
#                 "alias": "mediterranean",
#                 "title": "Mediterranean"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.790011,
#             "longitude": -96.804539
#         },
#         "display_phone": "(214) 281-8367",
#         "distance": 1639.3437626166226,
#         "id": "W2ULCcLTv5mp6VJqL6RviQ",
#         "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/qQxK8IjMUgARh5VOqPj4bQ/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "1919 McKinney Ave",
#             "address2": "",
#             "address3": null,
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "1919 McKinney Ave",
#                 "Dallas, TX 75201"
#             ],
#             "state": "TX",
#             "zip_code": "75201"
#         },
#         "name": "CAVA",
#         "phone": "+12142818367",
#         "rating": 5.0,
#         "review_count": 2,
#         "transactions": [],
#         "url": "https://www.yelp.com/biz/cava-dallas-2?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "the-woolworth-dallas",
#         "categories": [
#             {
#                 "alias": "cocktailbars",
#                 "title": "Cocktail Bars"
#             },
#             {
#                 "alias": "tapasmallplates",
#                 "title": "Tapas/Small Plates"
#             },
#             {
#                 "alias": "newamerican",
#                 "title": "American (New)"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.781324,
#             "longitude": -96.798692
#         },
#         "display_phone": "(214) 814-0588",
#         "distance": 537.9472400384784,
#         "id": "DP1I3daE5-mKznnAeA-Q3w",
#         "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/G2edTzjaqJY3UtcqAtb0Ww/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "1520 Elm St",
#             "address2": "Ste 201",
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "1520 Elm St",
#                 "Ste 201",
#                 "Dallas, TX 75204"
#             ],
#             "state": "TX",
#             "zip_code": "75204"
#         },
#         "name": "The Woolworth",
#         "phone": "+12148140588",
#         "price": "$$",
#         "rating": 4.0,
#         "review_count": 854,
#         "transactions": [
#             "restaurant_reservation",
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/the-woolworth-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "ellens-dallas-4",
#         "categories": [
#             {
#                 "alias": "southern",
#                 "title": "Southern"
#             },
#             {
#                 "alias": "tradamerican",
#                 "title": "American (Traditional)"
#             },
#             {
#                 "alias": "breakfast_brunch",
#                 "title": "Breakfast & Brunch"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.7818955295251,
#             "longitude": -96.8076125410698
#         },
#         "display_phone": "(469) 206-3339",
#         "distance": 1148.092401567593,
#         "id": "CREIs-59rrp8OhG9VppCqA",
#         "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/vGSmVFHrTYvz60loX2a-YQ/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "1790 N Record St",
#             "address2": null,
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "1790 N Record St",
#                 "Dallas, TX 75202"
#             ],
#             "state": "TX",
#             "zip_code": "75202"
#         },
#         "name": "Ellen's",
#         "phone": "+14692063339",
#         "price": "$$",
#         "rating": 4.0,
#         "review_count": 2539,
#         "transactions": [
#             "restaurant_reservation",
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/ellens-dallas-4?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "terry-blacks-barbecue-dallas",
#         "categories": [
#             {
#                 "alias": "bbq",
#                 "title": "Barbeque"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.78488,
#             "longitude": -96.77984
#         },
#         "display_phone": "(469) 399-0081",
#         "distance": 1839.2339784722094,
#         "id": "sqhaTs9xc3G8OWHihGBipQ",
#         "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/TcRzjwl316h7hDwcvH16EQ/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "3025 Main St",
#             "address2": null,
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "3025 Main St",
#                 "Dallas, TX 75226"
#             ],
#             "state": "TX",
#             "zip_code": "75226"
#         },
#         "name": "Terry Black's Barbecue",
#         "phone": "+14693990081",
#         "price": "$$",
#         "rating": 4.5,
#         "review_count": 143,
#         "transactions": [],
#         "url": "https://www.yelp.com/biz/terry-blacks-barbecue-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "meso-maya-comida-y-copas-dallas-4",
#         "categories": [
#             {
#                 "alias": "mexican",
#                 "title": "Mexican"
#             },
#             {
#                 "alias": "newmexican",
#                 "title": "New Mexican Cuisine"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.7877819354234,
#             "longitude": -96.8049378803092
#         },
#         "display_phone": "(214) 484-6555",
#         "distance": 1438.4451797301629,
#         "id": "vwQnJlj90NgYbbbVLQSpFg",
#         "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/WjnHLatNhe1iDFDsS1rP2Q/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "1611 McKinney Ave",
#             "address2": null,
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "1611 McKinney Ave",
#                 "Dallas, TX 75202"
#             ],
#             "state": "TX",
#             "zip_code": "75202"
#         },
#         "name": "Meso Maya Comida Y Copas",
#         "phone": "+12144846555",
#         "price": "$$",
#         "rating": 4.5,
#         "review_count": 2157,
#         "transactions": [
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/meso-maya-comida-y-copas-dallas-4?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "queso-beso-dallas",
#         "categories": [
#             {
#                 "alias": "tex-mex",
#                 "title": "Tex-Mex"
#             },
#             {
#                 "alias": "bars",
#                 "title": "Bars"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.7809724253327,
#             "longitude": -96.7985300538348
#         },
#         "display_phone": "(214) 922-7510",
#         "distance": 496.1393260722341,
#         "id": "DjptLpwx8pkhLSgllDzk5Q",
#         "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/SpmEJaBEUsYJGiGfb_6P8Q/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "1525 Main St",
#             "address2": "",
#             "address3": null,
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "1525 Main St",
#                 "Dallas, TX 75201"
#             ],
#             "state": "TX",
#             "zip_code": "75201"
#         },
#         "name": "Queso Beso",
#         "phone": "+12149227510",
#         "rating": 3.0,
#         "review_count": 24,
#         "transactions": [],
#         "url": "https://www.yelp.com/biz/queso-beso-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "cbd-provisions-dallas",
#         "categories": [
#             {
#                 "alias": "brasseries",
#                 "title": "Brasseries"
#             },
#             {
#                 "alias": "breakfast_brunch",
#                 "title": "Breakfast & Brunch"
#             },
#             {
#                 "alias": "tradamerican",
#                 "title": "American (Traditional)"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.780571,
#             "longitude": -96.7983932
#         },
#         "display_phone": "(214) 261-4500",
#         "distance": 465.74587718057234,
#         "id": "f6i2rU70xixptLYHfbtINg",
#         "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/NabuTSoFhAwCgoHNQEf5UA/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "1530 Main St",
#             "address2": null,
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "1530 Main St",
#                 "Dallas, TX 75201"
#             ],
#             "state": "TX",
#             "zip_code": "75201"
#         },
#         "name": "CBD Provisions",
#         "phone": "+12142614500",
#         "price": "$$",
#         "rating": 4.0,
#         "review_count": 981,
#         "transactions": [
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/cbd-provisions-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "twisted-trompo-dallas",
#         "categories": [
#             {
#                 "alias": "mexican",
#                 "title": "Mexican"
#             },
#             {
#                 "alias": "breakfast_brunch",
#                 "title": "Breakfast & Brunch"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.7795635919134,
#             "longitude": -96.8013510954492
#         },
#         "display_phone": "(214) 760-9599",
#         "distance": 516.5858154865499,
#         "id": "bB2ai7iXzB-CJFc1tcVXTw",
#         "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/PtWDdy9ZC12wIDrXZ09XBA/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "1211 Commerce St",
#             "address2": "",
#             "address3": null,
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "1211 Commerce St",
#                 "Dallas, TX 75202"
#             ],
#             "state": "TX",
#             "zip_code": "75202"
#         },
#         "name": "Twisted Trompo",
#         "phone": "+12147609599",
#         "price": "$",
#         "rating": 4.5,
#         "review_count": 275,
#         "transactions": [],
#         "url": "https://www.yelp.com/biz/twisted-trompo-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "babes-dallas",
#         "categories": [
#             {
#                 "alias": "tradamerican",
#                 "title": "American (Traditional)"
#             }
#         ],
#         "coordinates": {
#             "latitude": null,
#             "longitude": null
#         },
#         "display_phone": "",
#         "distance": 4.1383899887669875,
#         "id": "krhS1EeJS6wxHa6B8xVX3A",
#         "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/kiB5PASlkNn33wT7BiJvBw/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "",
#             "address2": "",
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "Dallas, TX"
#             ],
#             "state": "TX",
#             "zip_code": ""
#         },
#         "name": "Babe's",
#         "phone": "",
#         "rating": 5.0,
#         "review_count": 4,
#         "transactions": [],
#         "url": "https://www.yelp.com/biz/babes-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "texas-spice-dallas",
#         "categories": [
#             {
#                 "alias": "newamerican",
#                 "title": "American (New)"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.7758770087906,
#             "longitude": -96.8047791739758
#         },
#         "display_phone": "(214) 744-6664",
#         "distance": 733.0218472222596,
#         "id": "yVuzaTxmVo3VqClZ5ID7aw",
#         "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/fT50xTeWX1WmRHpTzwhKvw/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "555 S Lamar",
#             "address2": "",
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "555 S Lamar",
#                 "Dallas, TX 75202"
#             ],
#             "state": "TX",
#             "zip_code": "75202"
#         },
#         "name": "Texas Spice",
#         "phone": "+12147446664",
#         "price": "$$",
#         "rating": 4.0,
#         "review_count": 397,
#         "transactions": [
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/texas-spice-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "hero-dallas-3",
#         "categories": [
#             {
#                 "alias": "sportsbars",
#                 "title": "Sports Bars"
#             },
#             {
#                 "alias": "tradamerican",
#                 "title": "American (Traditional)"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.78939,
#             "longitude": -96.81065
#         },
#         "display_phone": "(469) 300-4199",
#         "distance": 1853.6744984941702,
#         "id": "84BI8_KZM28TpC6VCU7m-Q",
#         "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/E76rWqlMHOs3KV2lRqMBmQ/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "3090 Olive St",
#             "address2": "Ste b110",
#             "address3": null,
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "3090 Olive St",
#                 "Ste b110",
#                 "Dallas, TX 75219"
#             ],
#             "state": "TX",
#             "zip_code": "75219"
#         },
#         "name": "Hero",
#         "phone": "+14693004199",
#         "price": "$$",
#         "rating": 4.0,
#         "review_count": 193,
#         "transactions": [
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/hero-dallas-3?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "pacific-deck-dallas-dallas",
#         "categories": [
#             {
#                 "alias": "tradamerican",
#                 "title": "American (Traditional)"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.782646,
#             "longitude": -96.7953556
#         },
#         "display_phone": "(214) 609-0042",
#         "distance": 678.8016343506296,
#         "id": "mAH251fhS-hyWhK-RXkGaQ",
#         "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/jYGbISOZo3yr2T5fzYNN9g/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "1910 Pacific Ave",
#             "address2": "Ste 1400",
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "1910 Pacific Ave",
#                 "Ste 1400",
#                 "Dallas, TX 75201"
#             ],
#             "state": "TX",
#             "zip_code": "75201"
#         },
#         "name": "Pacific Deck Dallas",
#         "phone": "+12146090042",
#         "rating": 4.0,
#         "review_count": 29,
#         "transactions": [
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/pacific-deck-dallas-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "americano-dallas",
#         "categories": [
#             {
#                 "alias": "italian",
#                 "title": "Italian"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.780578,
#             "longitude": -96.7984
#         },
#         "display_phone": "(214) 261-4600",
#         "distance": 465.74587718057234,
#         "id": "Q8GUZIJVHAuhjWPNoL_VQg",
#         "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/WPtdtYh06qMLfvqnItmpsA/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "1530 Main St",
#             "address2": "",
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "1530 Main St",
#                 "Dallas, TX 75201"
#             ],
#             "state": "TX",
#             "zip_code": "75201"
#         },
#         "name": "Americano",
#         "phone": "+12142614600",
#         "price": "$$",
#         "rating": 4.0,
#         "review_count": 313,
#         "transactions": [
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/americano-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "turkey-leg-paradise-dallas-2",
#         "categories": [
#             {
#                 "alias": "bbq",
#                 "title": "Barbeque"
#             },
#             {
#                 "alias": "seafood",
#                 "title": "Seafood"
#             },
#             {
#                 "alias": "fishnchips",
#                 "title": "Fish & Chips"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.7656713912288,
#             "longitude": -96.7932187020779
#         },
#         "display_phone": "(469) 650-3427",
#         "distance": 1276.2683236132345,
#         "id": "C_JhahGralVzJZV7xJNtmg",
#         "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/4Xtzl3iSAHgpYaMVT7XLFA/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "1715 S Lamar St",
#             "address2": "",
#             "address3": null,
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "1715 S Lamar St",
#                 "Dallas, TX 75215"
#             ],
#             "state": "TX",
#             "zip_code": "75215"
#         },
#         "name": "Turkey Leg Paradise",
#         "phone": "+14696503427",
#         "price": "$$",
#         "rating": 3.0,
#         "review_count": 39,
#         "transactions": [],
#         "url": "https://www.yelp.com/biz/turkey-leg-paradise-dallas-2?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "ichigoh-ramen-lounge-dallas",
#         "categories": [
#             {
#                 "alias": "ramen",
#                 "title": "Ramen"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.782842,
#             "longitude": -96.783552
#         },
#         "display_phone": "(972) 707-0732",
#         "distance": 1425.3573839420678,
#         "id": "tNHmItQxcwtJX6RytsDXtQ",
#         "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/3RBHEz58o34MvzQ7h5KiYw/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "2724 Commerce St",
#             "address2": null,
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "2724 Commerce St",
#                 "Dallas, TX 75226"
#             ],
#             "state": "TX",
#             "zip_code": "75226"
#         },
#         "name": "Ichigoh Ramen Lounge",
#         "phone": "+19727070732",
#         "rating": 5.0,
#         "review_count": 55,
#         "transactions": [],
#         "url": "https://www.yelp.com/biz/ichigoh-ramen-lounge-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "dock-local-dallas",
#         "categories": [
#             {
#                 "alias": "seafood",
#                 "title": "Seafood"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.8091855437404,
#             "longitude": -96.7958156419886
#         },
#         "display_phone": "(972) 373-4587",
#         "distance": 3613.919708366121,
#         "id": "Ydaw9lu-gBExI7GgIsM7TA",
#         "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/lhj-We7LcB4OuGyYCMsbyg/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "3839 Mckinney Ave",
#             "address2": "Ste 150",
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "3839 Mckinney Ave",
#                 "Ste 150",
#                 "Dallas, TX 75204"
#             ],
#             "state": "TX",
#             "zip_code": "75204"
#         },
#         "name": "Dock Local",
#         "phone": "+19723734587",
#         "price": "$$",
#         "rating": 5.0,
#         "review_count": 19,
#         "transactions": [],
#         "url": "https://www.yelp.com/biz/dock-local-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "frankies-downtown-dallas-3",
#         "categories": [
#             {
#                 "alias": "sportsbars",
#                 "title": "Sports Bars"
#             },
#             {
#                 "alias": "tradamerican",
#                 "title": "American (Traditional)"
#             },
#             {
#                 "alias": "breakfast_brunch",
#                 "title": "Breakfast & Brunch"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.7803765266146,
#             "longitude": -96.8008640035987
#         },
#         "display_phone": "(214) 741-1919",
#         "distance": 545.5477564927534,
#         "id": "COpsoDr4gySfYDIMJ_qtEQ",
#         "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/15fjO0x1yyc-INT_00ndMg/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "1303 Main St",
#             "address2": null,
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "1303 Main St",
#                 "Dallas, TX 75202"
#             ],
#             "state": "TX",
#             "zip_code": "75202"
#         },
#         "name": "Frankie's Downtown",
#         "phone": "+12147411919",
#         "price": "$$",
#         "rating": 4.0,
#         "review_count": 471,
#         "transactions": [],
#         "url": "https://www.yelp.com/biz/frankies-downtown-dallas-3?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "bullion-dallas",
#         "categories": [
#             {
#                 "alias": "brasseries",
#                 "title": "Brasseries"
#             },
#             {
#                 "alias": "bars",
#                 "title": "Bars"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.77664,
#             "longitude": -96.805583
#         },
#         "display_phone": "(972) 698-4250",
#         "distance": 802.4623373468743,
#         "id": "OseLHyUULSVhYyyrr6okFg",
#         "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/LTCVRtqwvOVDZJar59W7dg/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "400 S Record St",
#             "address2": "Ste 150",
#             "address3": null,
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "400 S Record St",
#                 "Ste 150",
#                 "Dallas, TX 75202"
#             ],
#             "state": "TX",
#             "zip_code": "75202"
#         },
#         "name": "Bullion",
#         "phone": "+19726984250",
#         "price": "$$$",
#         "rating": 4.5,
#         "review_count": 163,
#         "transactions": [
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/bullion-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "off-the-bone-barbeque-dallas",
#         "categories": [
#             {
#                 "alias": "bbq",
#                 "title": "Barbeque"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.76581,
#             "longitude": -96.79229
#         },
#         "display_phone": "(214) 565-9551",
#         "distance": 1294.8843574254568,
#         "id": "WKqMvTM6Kt3MbQQFxWt5ZQ",
#         "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/lh99fsElFOtb_a4lzsauMA/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "1734 S Lamar St",
#             "address2": "",
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "1734 S Lamar St",
#                 "Dallas, TX 75215"
#             ],
#             "state": "TX",
#             "zip_code": "75215"
#         },
#         "name": "Off the Bone Barbeque",
#         "phone": "+12145659551",
#         "price": "$$",
#         "rating": 4.0,
#         "review_count": 618,
#         "transactions": [],
#         "url": "https://www.yelp.com/biz/off-the-bone-barbeque-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "the-biscuit-bar-dallas-3",
#         "categories": [
#             {
#                 "alias": "breakfast_brunch",
#                 "title": "Breakfast & Brunch"
#             },
#             {
#                 "alias": "bars",
#                 "title": "Bars"
#             },
#             {
#                 "alias": "newamerican",
#                 "title": "American (New)"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.784672,
#             "longitude": -96.788345
#         },
#         "display_phone": "(469) 638-9390",
#         "distance": 1244.8643902172407,
#         "id": "fydw3oFGHyXJPCtk-Jf_uQ",
#         "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Ggv3qvj91M4QsmJLBRA0Zg/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "2550 Pacific Ave",
#             "address2": "Ste 150",
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "2550 Pacific Ave",
#                 "Ste 150",
#                 "Dallas, TX 75226"
#             ],
#             "state": "TX",
#             "zip_code": "75226"
#         },
#         "name": "The Biscuit Bar",
#         "phone": "+14696389390",
#         "rating": 4.0,
#         "review_count": 49,
#         "transactions": [],
#         "url": "https://www.yelp.com/biz/the-biscuit-bar-dallas-3?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "wingbucket-dallas",
#         "categories": [
#             {
#                 "alias": "chicken_wings",
#                 "title": "Chicken Wings"
#             },
#             {
#                 "alias": "chickenshop",
#                 "title": "Chicken Shop"
#             },
#             {
#                 "alias": "soulfood",
#                 "title": "Soul Food"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.7800568007201,
#             "longitude": -96.8015836662705
#         },
#         "display_phone": "(214) 760-9491",
#         "distance": 568.2912796775189,
#         "id": "8B2asBf5t77_9V2RH20YPg",
#         "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/kgzv2fiD0wuZIcJBJbs23A/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "1200 Main St",
#             "address2": "",
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "1200 Main St",
#                 "Dallas, TX 75202"
#             ],
#             "state": "TX",
#             "zip_code": "75202"
#         },
#         "name": "WingBucket",
#         "phone": "+12147609491",
#         "price": "$$",
#         "rating": 4.0,
#         "review_count": 493,
#         "transactions": [
#             "pickup",
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/wingbucket-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "cutiepies-pizza-and-bar-dallas",
#         "categories": [
#             {
#                 "alias": "pizza",
#                 "title": "Pizza"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.8002897143007,
#             "longitude": -96.8006741514519
#         },
#         "display_phone": "(214) 238-6348",
#         "distance": 2645.44358362733,
#         "id": "hcZ0j9nCVGUiXdpfxnTH0w",
#         "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/26s2WvPIazSDTvfQQXBeZg/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "2916 McKinney Ave",
#             "address2": "",
#             "address3": null,
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "2916 McKinney Ave",
#                 "Dallas, TX 75204"
#             ],
#             "state": "TX",
#             "zip_code": "75204"
#         },
#         "name": "CutiePies Pizza and Bar",
#         "phone": "+12142386348",
#         "rating": 4.0,
#         "review_count": 15,
#         "transactions": [],
#         "url": "https://www.yelp.com/biz/cutiepies-pizza-and-bar-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "chop-house-burger-dallas",
#         "categories": [
#             {
#                 "alias": "burgers",
#                 "title": "Burgers"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.7807758,
#             "longitude": -96.7993548
#         },
#         "display_phone": "(214) 741-2747",
#         "distance": 503.8475681145049,
#         "id": "whIWTPTID5M4ooWp35dMDA",
#         "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/UtJfGHGfM68TMaK5-4JfPw/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "1501 Main St",
#             "address2": "",
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "1501 Main St",
#                 "Dallas, TX 75201"
#             ],
#             "state": "TX",
#             "zip_code": "75201"
#         },
#         "name": "Chop House Burger",
#         "phone": "+12147412747",
#         "price": "$$",
#         "rating": 4.0,
#         "review_count": 519,
#         "transactions": [
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/chop-house-burger-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "green-door-public-house-dallas",
#         "categories": [
#             {
#                 "alias": "bars",
#                 "title": "Bars"
#             },
#             {
#                 "alias": "tradamerican",
#                 "title": "American (Traditional)"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.778793,
#             "longitude": -96.791862
#         },
#         "display_phone": "(214) 749-0240",
#         "distance": 537.5550227881864,
#         "id": "xYXUm0gxR2Ax9cf6T4rDMQ",
#         "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Daxu5Gr0C31BwWl8n619oQ/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "600 S Harwood St",
#             "address2": "",
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "600 S Harwood St",
#                 "Dallas, TX 75201"
#             ],
#             "state": "TX",
#             "zip_code": "75201"
#         },
#         "name": "Green Door Public House",
#         "phone": "+12147490240",
#         "price": "$$",
#         "rating": 4.0,
#         "review_count": 211,
#         "transactions": [
#             "pickup",
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/green-door-public-house-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "toluca-organic-dallas",
#         "categories": [
#             {
#                 "alias": "vegan",
#                 "title": "Vegan"
#             },
#             {
#                 "alias": "tacos",
#                 "title": "Tacos"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.799985,
#             "longitude": -96.805037
#         },
#         "display_phone": "(214) 600-7927",
#         "distance": 2691.041897510839,
#         "id": "PZTzVcNS4ReiigSW9WTP5Q",
#         "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/QHmyQr3sl3GJrJH-F_vJzQ/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "2600 Cedar Springs Rd",
#             "address2": "",
#             "address3": null,
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "2600 Cedar Springs Rd",
#                 "Dallas, TX 75201"
#             ],
#             "state": "TX",
#             "zip_code": "75201"
#         },
#         "name": "Toluca Organic",
#         "phone": "+12146007927",
#         "rating": 5.0,
#         "review_count": 20,
#         "transactions": [
#             "pickup",
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/toluca-organic-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "partenope-ristorante-dallas",
#         "categories": [
#             {
#                 "alias": "italian",
#                 "title": "Italian"
#             },
#             {
#                 "alias": "pizza",
#                 "title": "Pizza"
#             },
#             {
#                 "alias": "wine_bars",
#                 "title": "Wine Bars"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.781576,
#             "longitude": -96.795623
#         },
#         "display_phone": "(214) 463-6222",
#         "distance": 557.2592636853047,
#         "id": "O8sGr3Co7K0EbvfcmdWCDw",
#         "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/QzWF5YKH7VgMFesTKr-W9w/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "1903 Main St",
#             "address2": "",
#             "address3": null,
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "1903 Main St",
#                 "Dallas, TX 75201"
#             ],
#             "state": "TX",
#             "zip_code": "75201"
#         },
#         "name": "Partenope Ristorante",
#         "phone": "+12144636222",
#         "price": "$$",
#         "rating": 4.5,
#         "review_count": 68,
#         "transactions": [],
#         "url": "https://www.yelp.com/biz/partenope-ristorante-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "hide-dallas",
#         "categories": [
#             {
#                 "alias": "cocktailbars",
#                 "title": "Cocktail Bars"
#             },
#             {
#                 "alias": "newamerican",
#                 "title": "American (New)"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.784559,
#             "longitude": -96.782935
#         },
#         "display_phone": "(214) 396-8050",
#         "distance": 1587.9225535831838,
#         "id": "RqJhbxQ7evXwR-quag_e7A",
#         "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/4nL3gKDimuDwWPRi1E0xig/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "2816 Elm St",
#             "address2": "",
#             "address3": null,
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "2816 Elm St",
#                 "Dallas, TX 75226"
#             ],
#             "state": "TX",
#             "zip_code": "75226"
#         },
#         "name": "Hide",
#         "phone": "+12143968050",
#         "price": "$$",
#         "rating": 4.5,
#         "review_count": 384,
#         "transactions": [
#             "pickup",
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/hide-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "the-crab-station-deep-ellum-dallas-dallas",
#         "categories": [
#             {
#                 "alias": "seafood",
#                 "title": "Seafood"
#             },
#             {
#                 "alias": "cajun",
#                 "title": "Cajun/Creole"
#             },
#             {
#                 "alias": "bars",
#                 "title": "Bars"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.78349,
#             "longitude": -96.7829
#         },
#         "display_phone": "(469) 941-4083",
#         "distance": 1545.1161662922652,
#         "id": "7qV39kauEp4S_HjHQj1Dng",
#         "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/sB7f8DWlRtApWQ4ShiRpNA/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "2813 Commerce St",
#             "address2": null,
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "2813 Commerce St",
#                 "Dallas, TX 75226"
#             ],
#             "state": "TX",
#             "zip_code": "75226"
#         },
#         "name": "The Crab Station - Deep Ellum Dallas",
#         "phone": "+14699414083",
#         "price": "$$",
#         "rating": 4.0,
#         "review_count": 93,
#         "transactions": [
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/the-crab-station-deep-ellum-dallas-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "cane-rosso-dallas",
#         "categories": [
#             {
#                 "alias": "pizza",
#                 "title": "Pizza"
#             },
#             {
#                 "alias": "italian",
#                 "title": "Italian"
#             },
#             {
#                 "alias": "breakfast_brunch",
#                 "title": "Breakfast & Brunch"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.782503,
#             "longitude": -96.785507
#         },
#         "display_phone": "(214) 741-1188",
#         "distance": 1253.325941190256,
#         "id": "kgmPMAHlFjWAILBGLUSKuw",
#         "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Pyfi7Y0YtFQjPS8pOIxT_A/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "2612 Commerce St",
#             "address2": "",
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "2612 Commerce St",
#                 "Dallas, TX 75226"
#             ],
#             "state": "TX",
#             "zip_code": "75226"
#         },
#         "name": "Cane Rosso",
#         "phone": "+12147411188",
#         "price": "$$",
#         "rating": 4.0,
#         "review_count": 1495,
#         "transactions": [
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/cane-rosso-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "five-sixty-dallas",
#         "categories": [
#             {
#                 "alias": "asianfusion",
#                 "title": "Asian Fusion"
#             },
#             {
#                 "alias": "sushi",
#                 "title": "Sushi Bars"
#             },
#             {
#                 "alias": "lounges",
#                 "title": "Lounges"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.77569,
#             "longitude": -96.80937
#         },
#         "display_phone": "(214) 571-5784",
#         "distance": 1195.4745261194948,
#         "id": "IFzwyWjcBP3gXzfhm3yBGg",
#         "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/8qjmkILjmb1ZFHmWZ1srww/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "300 Reunion Blvd",
#             "address2": "",
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "300 Reunion Blvd",
#                 "Dallas, TX 75207"
#             ],
#             "state": "TX",
#             "zip_code": "75207"
#         },
#         "name": "Five Sixty",
#         "phone": "+12145715784",
#         "price": "$$$",
#         "rating": 4.0,
#         "review_count": 1023,
#         "transactions": [],
#         "url": "https://www.yelp.com/biz/five-sixty-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "uchi-dallas",
#         "categories": [
#             {
#                 "alias": "japanese",
#                 "title": "Japanese"
#             },
#             {
#                 "alias": "sushi",
#                 "title": "Sushi Bars"
#             },
#             {
#                 "alias": "seafood",
#                 "title": "Seafood"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.79676,
#             "longitude": -96.8066599
#         },
#         "display_phone": "(214) 855-5454",
#         "distance": 2407.3338577653167,
#         "id": "CPQEBDq7cspBB_AFYHvTDw",
#         "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/poj8fLu3CA7vRzMi2FxUNg/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "2817 Maple Ave",
#             "address2": "",
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "2817 Maple Ave",
#                 "Dallas, TX 75201"
#             ],
#             "state": "TX",
#             "zip_code": "75201"
#         },
#         "name": "Uchi",
#         "phone": "+12148555454",
#         "price": "$$$",
#         "rating": 4.5,
#         "review_count": 1231,
#         "transactions": [],
#         "url": "https://www.yelp.com/biz/uchi-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "z\u00e5tar-dallas",
#         "categories": [
#             {
#                 "alias": "lebanese",
#                 "title": "Lebanese"
#             },
#             {
#                 "alias": "cocktailbars",
#                 "title": "Cocktail Bars"
#             },
#             {
#                 "alias": "hookah_bars",
#                 "title": "Hookah Bars"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.78362,
#             "longitude": -96.78219
#         },
#         "display_phone": "(972) 863-7100",
#         "distance": 1587.649682655343,
#         "id": "FXLFF81_BPzB3BlM7SqfnQ",
#         "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/klq1BR7E-R6KHyl5mU6vhg/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "2825 Commerce St",
#             "address2": "",
#             "address3": null,
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "2825 Commerce St",
#                 "Dallas, TX 75226"
#             ],
#             "state": "TX",
#             "zip_code": "75226"
#         },
#         "name": "Z\u00e5tar",
#         "phone": "+19728637100",
#         "price": "$$",
#         "rating": 4.0,
#         "review_count": 302,
#         "transactions": [
#             "restaurant_reservation",
#             "pickup",
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/z%C3%A5tar-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "rodeo-goat-dallas",
#         "categories": [
#             {
#                 "alias": "burgers",
#                 "title": "Burgers"
#             },
#             {
#                 "alias": "beerbar",
#                 "title": "Beer Bar"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.7971504231268,
#             "longitude": -96.8239863214264
#         },
#         "display_phone": "(214) 741-4628",
#         "distance": 3396.3158536992123,
#         "id": "bULVB0Q87mn4u2sNPjXTTQ",
#         "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/qpdC5Q9ImVZj_e6EL_lMRA/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "1926 Market Center Blvd",
#             "address2": "",
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "1926 Market Center Blvd",
#                 "Dallas, TX 75207"
#             ],
#             "state": "TX",
#             "zip_code": "75207"
#         },
#         "name": "Rodeo Goat",
#         "phone": "+12147414628",
#         "price": "$$",
#         "rating": 4.5,
#         "review_count": 1945,
#         "transactions": [
#             "delivery"
#         ],
# ...
#         "phone": "+12143031234",
#         "price": "$$",
#         "rating": 4.5,
#         "review_count": 181,
#         "transactions": [
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/caf%C3%A9-momentum-dallas-2?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "meddlesome-moth-dallas",
#         "categories": [
#             {
#                 "alias": "bars",
#                 "title": "Bars"
#             },
#             {
#                 "alias": "gastropubs",
#                 "title": "Gastropubs"
#             },
#             {
#                 "alias": "tradamerican",
#                 "title": "American (Traditional)"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.7968167432672,
#             "longitude": -96.8202942609787
#         },
#         "display_phone": "(214) 628-7900",
#         "distance": 3121.7606615596164,
#         "id": "vOsy9SLr3bjIkHPWFYxVWQ",
#         "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/qYAng2ZqsCMsJMfblMW02g/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "1621 Oak Lawn Ave",
#             "address2": "",
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "1621 Oak Lawn Ave",
#                 "Dallas, TX 75207"
#             ],
#             "state": "TX",
#             "zip_code": "75207"
#         },
#         "name": "Meddlesome Moth",
#         "phone": "+12146287900",
#         "price": "$$",
#         "rating": 4.0,
#         "review_count": 1874,
#         "transactions": [],
#         "url": "https://www.yelp.com/biz/meddlesome-moth-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "the-crafty-irishman-dallas",
#         "categories": [
#             {
#                 "alias": "irish_pubs",
#                 "title": "Irish Pub"
#             },
#             {
#                 "alias": "burgers",
#                 "title": "Burgers"
#             },
#             {
#                 "alias": "sandwiches",
#                 "title": "Sandwiches"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.7810448713128,
#             "longitude": -96.7961483448744
#         },
#         "display_phone": "(972) 707-7589",
#         "distance": 489.64394212192184,
#         "id": "WONOeHzleEpNRtZWj9DVzg",
#         "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/sx1npoPH7zHnsjsGrK94_g/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "1800 Main St",
#             "address2": "",
#             "address3": null,
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "1800 Main St",
#                 "Dallas, TX 75201"
#             ],
#             "state": "TX",
#             "zip_code": "75201"
#         },
#         "name": "The Crafty Irishman",
#         "phone": "+19727077589",
#         "price": "$$",
#         "rating": 4.5,
#         "review_count": 318,
#         "transactions": [
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/the-crafty-irishman-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "lucky-cat-vegan-dallas",
#         "categories": [
#             {
#                 "alias": "vegan",
#                 "title": "Vegan"
#             },
#             {
#                 "alias": "vegetarian",
#                 "title": "Vegetarian"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.77989,
#             "longitude": -96.79787
#         },
#         "display_phone": "",
#         "distance": 363.9171734875165,
#         "id": "zhOUCC2l4CcA_h_UyMQA_A",
#         "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/I8raM_0v8PyEwxb9KQOddQ/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "1512 Commerce St",
#             "address2": "Ste 101",
#             "address3": null,
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "1512 Commerce St",
#                 "Ste 101",
#                 "Dallas, TX 75201"
#             ],
#             "state": "TX",
#             "zip_code": "75201"
#         },
#         "name": "Lucky Cat Vegan",
#         "phone": "",
#         "rating": 4.0,
#         "review_count": 20,
#         "transactions": [
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/lucky-cat-vegan-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "angry-dog-dallas",
#         "categories": [
#             {
#                 "alias": "bars",
#                 "title": "Bars"
#             },
#             {
#                 "alias": "tradamerican",
#                 "title": "American (Traditional)"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.783003,
#             "longitude": -96.7835298
#         },
#         "display_phone": "(214) 741-4406",
#         "distance": 1433.2710441647894,
#         "id": "eTcckF6YCspz5M6SHATQZQ",
#         "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/st_kOte7rNw-fN0I3R62cw/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "2726 Commerce St",
#             "address2": "",
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "2726 Commerce St",
#                 "Dallas, TX 75226"
#             ],
#             "state": "TX",
#             "zip_code": "75226"
#         },
#         "name": "Angry Dog",
#         "phone": "+12147414406",
#         "price": "$$",
#         "rating": 4.0,
#         "review_count": 775,
#         "transactions": [
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/angry-dog-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "burgerim-westend-dallas-2",
#         "categories": [
#             {
#                 "alias": "burgers",
#                 "title": "Burgers"
#             },
#             {
#                 "alias": "chicken_wings",
#                 "title": "Chicken Wings"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.781798,
#             "longitude": -96.8067875
#         },
#         "display_phone": "(972) 707-7400",
#         "distance": 1076.3833524482804,
#         "id": "Tpg642Lckth7ALTrcCPaOw",
#         "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/VnkF2-NdNoma_-oODFXxCg/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "1722 N Market St",
#             "address2": null,
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "1722 N Market St",
#                 "Dallas, TX 75202"
#             ],
#             "state": "TX",
#             "zip_code": "75202"
#         },
#         "name": "Burgerim Westend",
#         "phone": "+19727077400",
#         "price": "$",
#         "rating": 3.5,
#         "review_count": 9,
#         "transactions": [],
#         "url": "https://www.yelp.com/biz/burgerim-westend-dallas-2?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "k-s-house-dallas",
#         "categories": [
#             {
#                 "alias": "korean",
#                 "title": "Korean"
#             },
#             {
#                 "alias": "bbq",
#                 "title": "Barbeque"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.7782929792805,
#             "longitude": -96.8279538154602
#         },
#         "display_phone": "(214) 238-2606",
#         "distance": 2899.2970612319186,
#         "id": "NGGcqovgvKOZwrUjKdfH4w",
#         "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/r6omUBea9Wg7-GIQsHEMtg/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "320 Singleton Blvd",
#             "address2": "Ste 100",
#             "address3": null,
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "320 Singleton Blvd",
#                 "Ste 100",
#                 "Dallas, TX 75212"
#             ],
#             "state": "TX",
#             "zip_code": "75212"
#         },
#         "name": "K\u2019s House",
#         "phone": "+12142382606",
#         "price": "$$",
#         "rating": 4.5,
#         "review_count": 134,
#         "transactions": [
#             "pickup",
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/k-s-house-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "sloanes-corner-dallas-2",
#         "categories": [
#             {
#                 "alias": "newamerican",
#                 "title": "American (New)"
#             },
#             {
#                 "alias": "cocktailbars",
#                 "title": "Cocktail Bars"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.78767,
#             "longitude": -96.79927
#         },
#         "display_phone": "(214) 484-1395",
#         "distance": 1260.7108301143837,
#         "id": "F90whnyHFeGIY4d4mL0ZQw",
#         "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/tUQMK_3Mbs4SBuaMNn1-zA/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "2001 Ross Ave",
#             "address2": "Ste 125",
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "2001 Ross Ave",
#                 "Ste 125",
#                 "Dallas, TX 75201"
#             ],
#             "state": "TX",
#             "zip_code": "75201"
#         },
#         "name": "Sloane's Corner",
#         "phone": "+12144841395",
#         "rating": 5.0,
#         "review_count": 17,
#         "transactions": [
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/sloanes-corner-dallas-2?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "open-palette-dallas-2",
#         "categories": [
#             {
#                 "alias": "newamerican",
#                 "title": "American (New)"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.78439,
#             "longitude": -96.79439
#         },
#         "display_phone": "(214) 922-8000",
#         "distance": 956.4313600172353,
#         "id": "qVhGX6IhpaRbhYv1iobO-g",
#         "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/QprNkKEf9RAVKdjkHtVgTw/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "400 North Olive Street",
#             "address2": null,
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "400 North Olive Street",
#                 "Dallas, TX 75201"
#             ],
#             "state": "TX",
#             "zip_code": "75201"
#         },
#         "name": "Open Palette",
#         "phone": "+12149228000",
#         "rating": 4.0,
#         "review_count": 18,
#         "transactions": [
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/open-palette-dallas-2?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "mikes-chicken-dallas",
#         "categories": [
#             {
#                 "alias": "chickenshop",
#                 "title": "Chicken Shop"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.808448,
#             "longitude": -96.818527
#         },
#         "display_phone": "(214) 443-7822",
#         "distance": 4075.0136797717546,
#         "id": "_m82_xIX_7WL4MQfw7CA5Q",
#         "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/GuO4yebC6DlK_T6aPNY2pg/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "4234 Maple Ave",
#             "address2": null,
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "4234 Maple Ave",
#                 "Dallas, TX 75219"
#             ],
#             "state": "TX",
#             "zip_code": "75219"
#         },
#         "name": "Mike's Chicken",
#         "phone": "+12144437822",
#         "price": "$",
#         "rating": 4.5,
#         "review_count": 956,
#         "transactions": [],
#         "url": "https://www.yelp.com/biz/mikes-chicken-dallas?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "bobs-steak-and-chop-house-dallas-2",
#         "categories": [
#             {
#                 "alias": "steak",
#                 "title": "Steakhouses"
#             },
#             {
#                 "alias": "seafood",
#                 "title": "Seafood"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.7750141257401,
#             "longitude": -96.8037885563446
#         },
#         "display_phone": "(214) 652-4804",
#         "distance": 661.7815176374208,
#         "id": "1jv0uZ_K1egUVhYm7eER5A",
#         "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/AGds2Xmu2fDjrik4mVt0NA/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "555 S Lamar St",
#             "address2": "",
#             "address3": "",
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "555 S Lamar St",
#                 "Dallas, TX 75202"
#             ],
#             "state": "TX",
#             "zip_code": "75202"
#         },
#         "name": "Bob's Steak & Chop House",
#         "phone": "+12146524804",
#         "price": "$$$",
#         "rating": 4.5,
#         "review_count": 217,
#         "transactions": [
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/bobs-steak-and-chop-house-dallas-2?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     },
#     {
#         "alias": "ruins-dallas-3",
#         "categories": [
#             {
#                 "alias": "mexican",
#                 "title": "Mexican"
#             },
#             {
#                 "alias": "cocktailbars",
#                 "title": "Cocktail Bars"
#             }
#         ],
#         "coordinates": {
#             "latitude": 32.78326,
#             "longitude": -96.78413
#         },
#         "display_phone": "(972) 707-0607",
#         "distance": 1404.8664559189028,
#         "id": "rjNZjcFx4_AuVMIaHq7-og",
#         "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/EuiroLHA0m5iZPUMUA6DKQ/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "2653 Commerce St",
#             "address2": "",
#             "address3": null,
#             "city": "Dallas",
#             "country": "US",
#             "display_address": [
#                 "2653 Commerce St",
#                 "Dallas, TX 75226"
#             ],
#             "state": "TX",
#             "zip_code": "75226"
#         },
#         "name": "Ruins",
#         "phone": "+19727070607",
#         "price": "$$",
#         "rating": 4.5,
#         "review_count": 204,
#         "transactions": [
#             "delivery"
#         ],
#         "url": "https://www.yelp.com/biz/ruins-dallas-3?adjust_creative=cqa3oghUiHI64DZLK-vRFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cqa3oghUiHI64DZLK-vRFw"
#     }
# ]

# %%
# create empty lists for the data
restaurant_categories = []
restaurant_category_1 = []
restaurant_category_2 = []
restaurant_category_3 = []
restaurant_latitude = []
restaurant_longitude = []
restaurant_display_phone = []
restaurant_distance = []
restaurant_id = []
restaurant_alias = []
restaurant_image_url = []
restaurant_is_closed = []
restaurant_address1 = []
restaurant_address2 = []
restaurant_address3 = []
restaurant_city = []
restaurant_country = []
restaurant_display_address = []
restaurant_state = []
restaurant_zip_code = []
restaurant_name = []
restaurant_phone = []
restaurant_price = []
restaurant_rating = []
restaurant_review_count = []
restaurant_url = []
restaurant_transactions = []
restaurant_region_center_lat = []
restaurant_region_center_long = []

missing_api_result = ""

# %%
# loop through yelp_results and add each component to its respective list
for i in range(len(yelp_results)):
    # not all results have > 1 category; in order to create dict, all lists must be same size - must assign "" when there is only one category
    if len(yelp_results[i]["categories"]) >= 1:
        restaurant_category_1.append(yelp_results[i]["categories"][0]["title"])
    else:
        restaurant_category_1.append(missing_api_result)
    if len(yelp_results[i]["categories"]) >= 2:
        restaurant_category_2.append(yelp_results[i]["categories"][1]["title"])
    else:
        restaurant_category_2.append(missing_api_result)
    if len(yelp_results[i]["categories"]) >= 3:
        restaurant_category_3.append(yelp_results[i]["categories"][2]["title"])
    else:
        restaurant_category_3.append(missing_api_result)
        
    restaurant_latitude.append(yelp_results[i]["coordinates"]["latitude"])
    restaurant_longitude.append(yelp_results[i]["coordinates"]["longitude"])
    restaurant_display_phone.append(yelp_results[i]["display_phone"])
    restaurant_distance.append(yelp_results[i]["distance"])
    restaurant_id.append(yelp_results[i]["id"])
    restaurant_alias.append(yelp_results[i]["alias"])
    restaurant_image_url.append(yelp_results[i]["image_url"])
    restaurant_is_closed.append(yelp_results[i]["is_closed"])
    restaurant_address1.append(yelp_results[i]["location"]["address1"])
    restaurant_address2.append(yelp_results[i]["location"]["address2"])
    restaurant_address3.append(yelp_results[i]["location"]["address3"])
    restaurant_city.append(yelp_results[i]["location"]["city"])
    restaurant_country.append(yelp_results[i]["location"]["country"])
    restaurant_display_address.append(yelp_results[i]["location"]["display_address"])
    restaurant_state.append(yelp_results[i]["location"]["state"])
    restaurant_zip_code.append(yelp_results[i]["location"]["zip_code"])
    restaurant_name.append(yelp_results[i]["name"])
    restaurant_phone.append(yelp_results[i]["phone"])
#     restaurant_price.append(yelp_results[i]["price"])
    # not all results have Price; to prevent error, try/except error handling, assigning "", all lists must be same size - must assign "" when there is no Price
    try:
        restaurant_price.append(yelp_results[i]["price"])
    except:
        restaurant_price.append(missing_api_result)
    restaurant_rating.append(yelp_results[i]["rating"])
    restaurant_review_count.append(yelp_results[i]["review_count"])
    restaurant_url.append(yelp_results[i]["url"])
#     restaurant_transactions.append(yelp_results[i]["transactions"])
    restaurant_region_center_lat.append(region_center_lat)
    restaurant_region_center_long.append(region_center_lat)

# %%
# create dictionary using the lists created from yelp_results json object
restaurant_dict = {"Name": restaurant_name,
#                    "Alias": restaurant_alias,
                   "Category1": restaurant_category_1,
                   "Category2": restaurant_category_2,
                   "Category3": restaurant_category_3,
                   "Rating": restaurant_rating,
                   "ReviewCount": restaurant_review_count,
                   "Price": restaurant_price,
                   "Lat": restaurant_latitude,
                   "Lng": restaurant_longitude,
                   "Address": restaurant_address1,
                   "Address2": restaurant_address2,
#                    "Address3": restaurant_address3,
                   "City": restaurant_city,
                   "State": restaurant_state,
#                    "Country": restaurant_country,
                   "Zip": restaurant_zip_code,
#                    "DisplayAddress": restaurant_display_address,
                   "Phone": restaurant_phone,
#                    "DisplayPhone": restaurant_display_phone,
#                    "ImageURL": restaurant_image_url,
#                    "URL": restaurant_url
#                    "Transactions": restaurant_transactions,
                   "Closed?": restaurant_is_closed,
                   "ID": restaurant_id,
                  }

# %%
# visualize dictionary
# restaurant_dict

# %%
# create data frame from dictionary 
restaurant_df = pd.DataFrame(restaurant_dict)

# %%
# visualize data frame
restaurant_df
# Out:
#                                     Name               Category1  \
# 0                            Pecan Lodge              Sandwiches
# 1                                   CAVA           Mediterranean
# 2                          The Woolworth           Cocktail Bars
# 3                                Ellen's                Southern
# 4                 Terry Black's Barbecue                Barbeque
# 5               Meso Maya Comida Y Copas                 Mexican
# 6                             Queso Beso                 Tex-Mex
# 7                         CBD Provisions              Brasseries
# 8                         Twisted Trompo                 Mexican
# 9                                 Babe's  American (Traditional)
# 10                           Texas Spice          American (New)
# 11                                  Hero             Sports Bars
# 12                   Pacific Deck Dallas  American (Traditional)
# 13                             Americano                 Italian
# 14                   Turkey Leg Paradise                Barbeque
# 15                  Ichigoh Ramen Lounge                   Ramen
# 16                            Dock Local                 Seafood
# 17                    Frankie's Downtown             Sports Bars
# 18                               Bullion              Brasseries
# 19                 Off the Bone Barbeque                Barbeque
# 20                       The Biscuit Bar      Breakfast & Brunch
# 21                            WingBucket           Chicken Wings
# 22               CutiePies Pizza and Bar                   Pizza
# 23                     Chop House Burger                 Burgers
# 24               Green Door Public House                    Bars
# 25                        Toluca Organic                   Vegan
# 26                  Partenope Ristorante                 Italian
# 27                                  Hide           Cocktail Bars
# 28  The Crab Station - Deep Ellum Dallas                 Seafood
# 29                            Cane Rosso                   Pizza
# 30                            Five Sixty            Asian Fusion
# 31                                  Uchi                Japanese
# 32                                 Zåtar                Lebanese
# 33                            Rodeo Goat                 Burgers
# 34                          Uncle Uber's              Sandwiches
# 35              Big Guy's Chicken & Rice           Mediterranean
# 36              Spice In The City Dallas                  Indian
# 37                  Water Grill - Dallas                 Seafood
# 38                         Café Momentum          American (New)
# 39                       Meddlesome Moth                    Bars
# 40                   The Crafty Irishman               Irish Pub
# 41                       Lucky Cat Vegan                   Vegan
# 42                             Angry Dog                    Bars
# 43                      Burgerim Westend                 Burgers
# 44                             K’s House                  Korean
# 45                       Sloane's Corner          American (New)
# 46                          Open Palette          American (New)
# 47                        Mike's Chicken            Chicken Shop
# 48              Bob's Steak & Chop House             Steakhouses
# 49                                 Ruins                 Mexican
#
#                  Category2               Category3  Rating  ReviewCount Price  \
# 0                 Barbeque                             4.5         4779    $$
# 1                                                      5.0            2
# 2       Tapas/Small Plates          American (New)     4.0          854    $$
# 3   American (Traditional)      Breakfast & Brunch     4.0         2539    $$
# 4                                                      4.5          143    $$
# 5      New Mexican Cuisine                             4.5         2157    $$
# 6                     Bars                             3.0           24
# 7       Breakfast & Brunch  American (Traditional)     4.0          981    $$
# 8       Breakfast & Brunch                             4.5          275     $
# 9                                                      5.0            4
# 10                                                     4.0          397    $$
# 11  American (Traditional)                             4.0          193    $$
# 12                                                     4.0           29
# 13                                                     4.0          313    $$
# 14                 Seafood            Fish & Chips     3.0           39    $$
# 15                                                     5.0           55
# 16                                                     5.0           19    $$
# 17  American (Traditional)      Breakfast & Brunch     4.0          471    $$
# 18                    Bars                             4.5          163   $$$
# 19                                                     4.0          618    $$
# 20                    Bars          American (New)     4.0           49
# 21            Chicken Shop               Soul Food     4.0          493    $$
# 22                                                     4.0           15
# 23                                                     4.0          519    $$
# 24  American (Traditional)                             4.0          211    $$
# 25                   Tacos                             5.0           20
# 26                   Pizza               Wine Bars     4.5           68    $$
# 27          American (New)                             4.5          384    $$
# 28            Cajun/Creole                    Bars     4.0           93    $$
# 29                 Italian      Breakfast & Brunch     4.0         1495    $$
# 30              Sushi Bars                 Lounges     4.0         1023   $$$
# 31              Sushi Bars                 Seafood     4.5         1231   $$$
# 32           Cocktail Bars             Hookah Bars     4.0          302    $$
# 33                Beer Bar                             4.5         1945    $$
# 34                 Burgers                    Bars     4.5         1210     $
# 35               Fast Food          Middle Eastern     4.0          334     $
# 36                 Tex-Mex                   Halal     4.0          414    $$
# 37                                                     4.0          377   $$$
# 38                                                     4.5          181    $$
# 39              Gastropubs  American (Traditional)     4.0         1874    $$
# 40                 Burgers              Sandwiches     4.5          318    $$
# 41              Vegetarian                             4.0           20
# 42  American (Traditional)                             4.0          775    $$
# 43           Chicken Wings                             3.5            9     $
# 44                Barbeque                             4.5          134    $$
# 45           Cocktail Bars                             5.0           17
# 46                                                     4.0           18
# 47                                                     4.5          956     $
# 48                 Seafood                             4.5          217   $$$
# 49           Cocktail Bars                             4.5          204    $$
#
#           Lat        Lng                  Address  Address2    City State  \
# 0   32.783588 -96.783867             2702 Main St            Dallas    TX
# 1   32.790011 -96.804539        1919 McKinney Ave            Dallas    TX
# 2   32.781324 -96.798692              1520 Elm St   Ste 201  Dallas    TX
# 3   32.781896 -96.807613         1790 N Record St      None  Dallas    TX
# 4   32.784880 -96.779840             3025 Main St      None  Dallas    TX
# 5   32.787782 -96.804938        1611 McKinney Ave      None  Dallas    TX
# 6   32.780972 -96.798530             1525 Main St            Dallas    TX
# 7   32.780571 -96.798393             1530 Main St      None  Dallas    TX
# 8   32.779564 -96.801351         1211 Commerce St            Dallas    TX
# 9         NaN        NaN                                     Dallas    TX
# 10  32.775877 -96.804779              555 S Lamar            Dallas    TX
# 11  32.789390 -96.810650            3090 Olive St  Ste b110  Dallas    TX
# 12  32.782646 -96.795356         1910 Pacific Ave  Ste 1400  Dallas    TX
# 13  32.780578 -96.798400             1530 Main St            Dallas    TX
# 14  32.765671 -96.793219          1715 S Lamar St            Dallas    TX
# 15  32.782842 -96.783552         2724 Commerce St      None  Dallas    TX
# 16  32.809186 -96.795816        3839 Mckinney Ave   Ste 150  Dallas    TX
# 17  32.780377 -96.800864             1303 Main St      None  Dallas    TX
# 18  32.776640 -96.805583          400 S Record St   Ste 150  Dallas    TX
# 19  32.765810 -96.792290          1734 S Lamar St            Dallas    TX
# 20  32.784672 -96.788345         2550 Pacific Ave   Ste 150  Dallas    TX
# 21  32.780057 -96.801584             1200 Main St            Dallas    TX
# 22  32.800290 -96.800674        2916 McKinney Ave            Dallas    TX
# 23  32.780776 -96.799355             1501 Main St            Dallas    TX
# 24  32.778793 -96.791862         600 S Harwood St            Dallas    TX
# 25  32.799985 -96.805037    2600 Cedar Springs Rd            Dallas    TX
# 26  32.781576 -96.795623             1903 Main St            Dallas    TX
# 27  32.784559 -96.782935              2816 Elm St            Dallas    TX
# 28  32.783490 -96.782900         2813 Commerce St      None  Dallas    TX
# 29  32.782503 -96.785507         2612 Commerce St            Dallas    TX
# 30  32.775690 -96.809370         300 Reunion Blvd            Dallas    TX
# 31  32.796760 -96.806660           2817 Maple Ave            Dallas    TX
# 32  32.783620 -96.782190         2825 Commerce St            Dallas    TX
# 33  32.797150 -96.823986  1926 Market Center Blvd            Dallas    TX
# 34  32.783400 -96.783410         2713 Commerce St            Dallas    TX
# 35  32.783990 -96.785890              2614 Elm St   Ste 130  Dallas    TX
# 36  32.779890 -96.797870         1512 Commerce St   Ste 100  Dallas    TX
# 37  32.790170 -96.803520            1920 McKinney   Ste 100  Dallas    TX
# 38  32.782132 -96.799304         1510 Pacific Ave            Dallas    TX
# 39  32.796817 -96.820294        1621 Oak Lawn Ave            Dallas    TX
# 40  32.781045 -96.796148             1800 Main St            Dallas    TX
# 41  32.779890 -96.797870         1512 Commerce St   Ste 101  Dallas    TX
# 42  32.783003 -96.783530         2726 Commerce St            Dallas    TX
# 43  32.781798 -96.806787         1722 N Market St      None  Dallas    TX
# 44  32.778293 -96.827954       320 Singleton Blvd   Ste 100  Dallas    TX
# 45  32.787670 -96.799270            2001 Ross Ave   Ste 125  Dallas    TX
# 46  32.784390 -96.794390   400 North Olive Street      None  Dallas    TX
# 47  32.808448 -96.818527           4234 Maple Ave      None  Dallas    TX
# 48  32.775014 -96.803789           555 S Lamar St            Dallas    TX
# 49  32.783260 -96.784130         2653 Commerce St            Dallas    TX
#
#       Zip         Phone  Closed?                      ID
# 0   75226  +12147488900    False  ycL1qii6EpKXoLgMMboBIQ
# 1   75201  +12142818367    False  W2ULCcLTv5mp6VJqL6RviQ
# 2   75204  +12148140588    False  DP1I3daE5-mKznnAeA-Q3w
# 3   75202  +14692063339    False  CREIs-59rrp8OhG9VppCqA
# 4   75226  +14693990081    False  sqhaTs9xc3G8OWHihGBipQ
# 5   75202  +12144846555    False  vwQnJlj90NgYbbbVLQSpFg
# 6   75201  +12149227510    False  DjptLpwx8pkhLSgllDzk5Q
# 7   75201  +12142614500    False  f6i2rU70xixptLYHfbtINg
# 8   75202  +12147609599    False  bB2ai7iXzB-CJFc1tcVXTw
# 9                          False  krhS1EeJS6wxHa6B8xVX3A
# 10  75202  +12147446664    False  yVuzaTxmVo3VqClZ5ID7aw
# 11  75219  +14693004199    False  84BI8_KZM28TpC6VCU7m-Q
# 12  75201  +12146090042    False  mAH251fhS-hyWhK-RXkGaQ
# 13  75201  +12142614600    False  Q8GUZIJVHAuhjWPNoL_VQg
# 14  75215  +14696503427    False  C_JhahGralVzJZV7xJNtmg
# 15  75226  +19727070732    False  tNHmItQxcwtJX6RytsDXtQ
# 16  75204  +19723734587    False  Ydaw9lu-gBExI7GgIsM7TA
# 17  75202  +12147411919    False  COpsoDr4gySfYDIMJ_qtEQ
# 18  75202  +19726984250    False  OseLHyUULSVhYyyrr6okFg
# 19  75215  +12145659551    False  WKqMvTM6Kt3MbQQFxWt5ZQ
# 20  75226  +14696389390    False  fydw3oFGHyXJPCtk-Jf_uQ
# 21  75202  +12147609491    False  8B2asBf5t77_9V2RH20YPg
# 22  75204  +12142386348    False  hcZ0j9nCVGUiXdpfxnTH0w
# 23  75201  +12147412747    False  whIWTPTID5M4ooWp35dMDA
# 24  75201  +12147490240    False  xYXUm0gxR2Ax9cf6T4rDMQ
# 25  75201  +12146007927    False  PZTzVcNS4ReiigSW9WTP5Q
# 26  75201  +12144636222    False  O8sGr3Co7K0EbvfcmdWCDw
# 27  75226  +12143968050    False  RqJhbxQ7evXwR-quag_e7A
# 28  75226  +14699414083    False  7qV39kauEp4S_HjHQj1Dng
# 29  75226  +12147411188    False  kgmPMAHlFjWAILBGLUSKuw
# 30  75207  +12145715784    False  IFzwyWjcBP3gXzfhm3yBGg
# 31  75201  +12148555454    False  CPQEBDq7cspBB_AFYHvTDw
# 32  75226  +19728637100    False  FXLFF81_BPzB3BlM7SqfnQ
# 33  75207  +12147414628    False  bULVB0Q87mn4u2sNPjXTTQ
# 34  75226  +12146538237    False  kvcQrj5CutHBfSgcg236EA
# 35  75226  +12148101955    False  93ZroBgXyfvTGv8qLy8QGg
# 36  75201  +14695540348    False  K6WTnxvhq8ppvj8v7TtQHA
# 37  75201  +12143067111    False  PO-JH9O6uPihW3fXTAuYrg
# 38  75201  +12143031234    False  -u5VKytWtYYiYf7RdJ3UDA
# 39  75207  +12146287900    False  vOsy9SLr3bjIkHPWFYxVWQ
# 40  75201  +19727077589    False  WONOeHzleEpNRtZWj9DVzg
# 41  75201                  False  zhOUCC2l4CcA_h_UyMQA_A
# 42  75226  +12147414406    False  eTcckF6YCspz5M6SHATQZQ
# 43  75202  +19727077400    False  Tpg642Lckth7ALTrcCPaOw
# 44  75212  +12142382606    False  NGGcqovgvKOZwrUjKdfH4w
# 45  75201  +12144841395    False  F90whnyHFeGIY4d4mL0ZQw
# 46  75201  +12149228000    False  qVhGX6IhpaRbhYv1iobO-g
# 47  75219  +12144437822    False  _m82_xIX_7WL4MQfw7CA5Q
# 48  75202  +12146524804    False  1jv0uZ_K1egUVhYm7eER5A
# 49  75226  +19727070607    False  rjNZjcFx4_AuVMIaHq7-og
