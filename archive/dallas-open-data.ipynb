# %%
# Dependencies
import pandas as pd
#import os
#import sys
import csv
import json

# %%
# Load in csv file
dallas_open_data = 'dataset_dallas_open_data/Restaurant_and_Food_Establishment_Inspections__October_2016_to_Present_.csv'

# %%
# Read and display the CSV with Pandas
dallas_open_data_pd = pd.read_csv(dallas_open_data)
dallas_open_data_pd.head()
# Out:
# C:\Users\KDSharp\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (10,97,107,109,110) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#              Restaurant Name Inspection Type Inspection Date  \
# 0                    FRESHII         Routine      10/31/2018
# 1             MICKLE CHICKEN         Routine      10/30/2019
# 2  WORLD TRADE CENTER MARKET         Routine      11/03/2016
# 3              DUNKIN DONUTS         Routine      10/30/2019
# 4   CANVAS HOTEL - 6TH FLOOR         Routine      06/11/2018
#
#    Inspection Score  Street Number    Street Name Street Direction  \
# 0                96           2414   VICTORY PARK              NaN
# 1               100           3203    CAMP WISDOM                W
# 2               100           2050       STEMMONS                N
# 3                99           8008  HERB KELLEHER              NaN
# 4               100           1325          LAMAR                S
#
#   Street Type Street Unit                     Street Address  ...  \
# 0          LN         NaN               2414 VICTORY PARK LN  ...
# 1          RD         NaN              3203 W CAMP WISDOM RD  ...
# 2        FRWY         NaN               2050 N STEMMONS FRWY  ...
# 3         WAY       C2174  8008 HERB KELLEHER WAY STE# C2174  ...
# 4          ST         NaN                    1325 S LAMAR ST  ...
#
#   Violation Points - 24 Violation Detail - 24  Violation Memo - 24  \
# 0                   NaN                   NaN                  NaN
# 1                   NaN                   NaN                  NaN
# 2                   NaN                   NaN                  NaN
# 3                   NaN                   NaN                  NaN
# 4                   NaN                   NaN                  NaN
#
#   Violation Description - 25 Violation Points - 25 Violation Detail - 25  \
# 0                        NaN                   NaN                   NaN
# 1                        NaN                   NaN                   NaN
# 2                        NaN                   NaN                   NaN
# 3                        NaN                   NaN                   NaN
# 4                        NaN                   NaN                   NaN
#
#    Violation Memo - 25 Inspection Month Inspection Year  \
# 0                  NaN         Oct 2018          FY2019
# 1                  NaN         Oct 2019          FY2020
# 2                  NaN         Nov 2016          FY2017
# 3                  NaN         Oct 2019          FY2020
# 4                  NaN         Jun 2018          FY2018
#
#                                 Lat Long Location
# 0   2414 VICTORY PARK LN\n(32.787625, -96.809294)
# 1  3203 W CAMP WISDOM RD\n(32.662584, -96.873446)
# 2   2050 N STEMMONS FRWY\n(32.801934, -96.825878)
# 3               8008 HERB KELLEHER WAY STE# C2174
# 4        1325 S LAMAR ST\n(39.69335, -105.067425)
#
# [5 rows x 114 columns]

# %%
# Extract specific columns for analysis

restaurant_name = dallas_open_data_pd['Restaurant Name'].str.strip()
inspection_type = dallas_open_data_pd['Inspection Type'].str.strip()
inspection_date = dallas_open_data_pd['Inspection Date'].str.strip()
inspection_score = dallas_open_data_pd['Inspection Score']
street_number = dallas_open_data_pd['Street Number'].astype('str').str.strip()
street_name = dallas_open_data_pd['Street Name'].str.strip()
street_unit = dallas_open_data_pd['Street Unit'].fillna('').astype('str').str.strip()
zip_code = dallas_open_data_pd['Zip Code'].str.strip()
street_address = dallas_open_data_pd['Street Address'].str.strip()
inspection_month = dallas_open_data_pd['Inspection Month'].str.strip()
inspection_year = dallas_open_data_pd['Inspection Year'].str.strip()

# Check record count.  Should be 42,070
len(restaurant_name)
# Out:
# 42070

# %%
## Parse the 'Lat Long Location' column to capture lat/long separately

# Isolate 'Lat Long Location' column
lat_long_location = dallas_open_data_pd['Lat Long Location']

# Separate out only the lat and long
lat_long = dallas_open_data_pd['Lat Long Location'].str.split('\n').str[1]

# Remove parenthesis
lat_long = lat_long.astype(str).str.lstrip('(').str.rstrip(')')

# Return only the lat
lat = lat_long.str.split(',').str[0].str.replace('nan','0').fillna(0)

# Return only the long
long = lat_long.str.split(',').str[1].str.replace('nan','0').fillna(0)

# %%
#Save data tp dataframe
clean_dallas_open_data_pd = pd.DataFrame({
    'restaurant_name':restaurant_name,
    'inspection_type':inspection_type,
    'inspection_date':inspection_date,
    'inspection_score':inspection_score,
    'street_number':street_number,
    'street_name':street_name,
    'street_unit':street_unit,
    'zip_code':zip_code,
    'street_address':street_address,
    'inspection_month':inspection_month,
    'inspection_year':inspection_year,
    'lat':lat,
    'long':long
})

# Display dataframe
clean_dallas_open_data_pd

# %%
# Output File (CSV)
#clean_dallas_open_data_output = "./dataset_dallas_open_data/clean_dallas_open_data.csv"

# write dataframe to the csv
#clean_dallas_open_data_pd.to_csv(clean_dallas_open_data_output, sep=',', encoding='utf-8', index=False)

# %%
# Output File (JSON)
#clean_dallas_open_data_pd.to_json(r'./dataset_dallas_open_data/clean_dallas_open_data.json')

# %%
inspection_month_is_2019 = clean_dallas_open_data_pd[
    clean_dallas_open_data_pd['inspection_month'].str.split(expand=True)[1] == str(2019)
]
inspection_month_is_2019

# %%
# Output File (CSV)
dal_open_data_2019_inspection_month_output = "./dataset_dallas_open_data/dal_open_data_2019_inspection_month.csv"

# write dataframe to the csv
inspection_month_is_2019.to_csv(dal_open_data_2019_inspection_month_output, sep=',', encoding='utf-8', index=False)
